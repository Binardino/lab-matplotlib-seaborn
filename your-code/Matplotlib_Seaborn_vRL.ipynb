# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties
# %matplotlib inline
import pandas as pd
import seaborn as sns
import sqlalchemy

# %% [markdown]
# ## Challenge 1
#
# #### The data we will use in this challenge is:

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x, y) and (x, z).
# There are 2 ways of doing this. Do in both ways.
#
# **Hint**: Check out the nrows, ncols and index arguments of subplots.
#
# Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
plt_plot_1 = plt.plot(x,y,  linestyle='dashed')

# %%
plt_plot_2 = plt.plot(x,z, linewidth=3)

# %%
sns_plot_1 = sns.lineplot(x,y)

# %%
sns_plot_2 = sns.lineplot(x,z)

# %% [markdown]
# #### Use plt.subplots(nrows=1, ncols=2) to create the plot.

# %%
#Two ways of subploting, way#1 here with ax[0] & ax[1]
subplot_1, ax = plt.subplots(nrows=1, ncols=2, figsize=(20, 10))
ax[0].plot(x,y)
ax[1].plot(x,z)

# %%
#Two ways of subploting, way#2 here with ax1 & ax2
subplot_2, [ax1, ax2] = plt.subplots(nrows=1, ncols=2, figsize=(30, 5))
ax1.plot(x,y)
ax2.plot(x,z)
ax1.set_xlabel('x label')
ax1.set_ylabel('y label')

ax2.set_xlabel('x label')
ax2.set_ylabel('y label')
# Out:
# Text(0, 0.5, 'y label')

# %% [markdown]
# #### Use your previous code but now, resize your plot.
# **Hint**: Add the figsize argument in plt.subplots().
#
# If you want, try to add a title to the plot or even axes labels. You can also play with the fontweight and fontsize of the titles and labels.

# %%
subplot_2, [ax1, ax2] = plt.subplots(nrows=1, ncols=2, figsize=(20, 10))
ax1.plot(x,y)
ax2.plot(x,z)
ax1.set_title('linear title try 1')
ax1.set_xlabel('x label', fontsize='xx-large', fontweight='bold')
ax1.set_ylabel('y label')

ax2.set_title('curby title try 2')
ax2.set_xlabel('x label')
ax2.set_ylabel('y label', fontsize='small', fontweight='demibold')
# Out:
# Text(0, 0.5, 'y label')

# %% [markdown]
# #### Now you will have to plot both $y=x^2$ and $y=e^x$ in the same plot. Create two subplots and use a normal scale in the first one and a logarithmic scale in the second one.
# **Hint**: Use `set_xscale` and `set_yscale`.

# %%
y = x**2 
y_bis = np.exp(x)
x = np.arange(0, 100)

# %%
#linear
subplot_sq, ax_sq = plt.subplots(nrows = 1, ncols = 1, figsize = (20,10))
ax_sq.plot(x, x**2, 'r', x, np.exp(x), 'g')
ax_sq.set_xscale('linear')
ax_sq.set_yscale('linear')
# plt.show()

#log
ax_sq.plot(x, y, 'r', x, y_bis, 'g')
ax_sq.set_yscale('log')

# %% [markdown]
# #### As a bonus challenge, try to add a legend to the plot.

# %%
#linear
subplot_sq, ax_sq = plt.subplots(nrows = 1, ncols = 1, figsize = (20,10))
ax_sq.plot(x, x**2, 'r', x, np.exp(x), 'g')
ax_sq.set_xscale('linear')
ax_sq.set_yscale('linear')
# plt.show()

#log
ax_sq.plot(x, y, 'r', x, y_bis, 'g')
ax_sq.set_yscale('log')

ax_sq.set_title('x squared VS. exp(x), the great battle', fontsize='xx-large', fontweight='bold')
ax1.set_xlabel('x linear scale', fontsize='xx-large', fontweight='bold')
ax1.set_ylabel('y log scale')
# Out:
# Text(17.200000000000017, 0.5, 'y log scale')

# %% [markdown]
# ## Challenge 2
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
import pymysql
from sqlalchemy import create_engine
driver = 'mysql+pymysql:'
driver   = 'mysql+pymysql:'
user     = 'data-students'
password = 'iR0nH@cK-D4T4B4S3'
ip       = '34.65.10.136'
database = 'fitbit'
connection_string = f'{driver}//{user}:{password}@{ip}/{database}'
print(connection_string)

engine = create_engine(connection_string)
# Out:
# mysql+pymysql://data-students:iR0nH@cK-D4T4B4S3@34.65.10.136/fitbit

# %%
pd.read_sql('SHOW TABLES', engine)
# Out:
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# c:\users\binardo surface\appdata\local\programs\python\python38\lib\site-packages\pymysql\connections.py in connect(self, sock)
#     580                         try:
# --> 581                             sock = socket.create_connection(
#     582                                 (self.host, self.port), self.connect_timeout,
#
# c:\users\binardo surface\appdata\local\programs\python\python38\lib\socket.py in create_connection(address, timeout, source_address)
#     806     if err is not None:
# --> 807         raise err
#     808     else:
#
# c:\users\binardo surface\appdata\local\programs\python\python38\lib\socket.py in create_connection(address, timeout, source_address)
#     795                 sock.bind(source_address)
# --> 796             sock.connect(sa)
#     797             # Break explicitly a reference cycle
#
# ...

# %%
df_fitbit = pd.read_sql('SELECT * FROM fitbit', engine)

# %%
df_fitbit2 = pd.read_sql('SELECT * FROM fitbit2', engine)
# Out:
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# c:\users\binardo surface\appdata\local\programs\python\python38\lib\site-packages\pymysql\connections.py in connect(self, sock)
#     580                         try:
# --> 581                             sock = socket.create_connection(
#     582                                 (self.host, self.port), self.connect_timeout,
#
# c:\users\binardo surface\appdata\local\programs\python\python38\lib\socket.py in create_connection(address, timeout, source_address)
#     806     if err is not None:
# --> 807         raise err
#     808     else:
#
# c:\users\binardo surface\appdata\local\programs\python\python38\lib\socket.py in create_connection(address, timeout, source_address)
#     795                 sock.bind(source_address)
# --> 796             sock.connect(sa)
#     797             # Break explicitly a reference cycle
#
# ...

# %%
df_fitbit.to_csv('fitbit.csv')

df_fitbit

# %%
df_fitbit2.to_csv('fitbit2.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-9d615a57fc4a> in <module>
# ----> 1 df_fitbit2.to_csv('fitbit2.csv')
#
# NameError: name 'df_fitbit2' is not defined

# %%
df_fitbit2 = pd.read_csv('fitbit2.csv')

# %%
df_fitbit2
# Out:
#      Unnamed: 0        Date  Calorie burned  Steps  Distance  Floors  \
# 0             0  2015-05-08            1934    905      0.65       0
# 1             1  2015-05-09            3631  18925     14.11       4
# 2             2  2015-05-10            3204  14228     10.57       1
# 3             3  2015-05-11            2673   6756      5.02       8
# 4             4  2015-05-12            2495    502      3.73       1
# ..          ...         ...             ...    ...       ...     ...
# 362         362  2016-05-03            3796  18588     14.13      16
# 363         363  2016-05-04            3525  16382     12.39      16
# 364         364  2016-05-05            3649  21913     16.40      19
# 365         365  2016-05-06            3539  19023     14.79      15
# 366         366  2016-05-07             304   9526      7.08       2
#
#      Minutes Sedentary  Minutes Lightly Active  Minutes Fairly Active  \
# ...

# %%
df_fitbit2.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'Calorie burned', 'Steps', 'Distance', 'Floors',
#        'Minutes Sedentary', 'Minutes Lightly Active', 'Minutes Fairly Active',
#        'Minutes Very Active', 'Activity Calories', 'MinutesOfSleep',
#        'MinutesOfBeingAwake', 'NumberOfAwakings', 'LengthOfRestInMinutes',
#        'Distance_miles', 'Days', 'Days_encoded', 'Work_or_Weekend',
#        'Hours Sleep', 'Sleep efficiency', 'Yesterday_sleep',
#        'Yesterday_sleep_efficiency', 'Months', 'Months_encoded'],
#       dtype='object')

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays? All plots must be in the same jupyter notebook cell.
#
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
steps_median = df_fitbit2.groupby('Months').agg({'Steps':'median'})
steps_median
# Out:
#              Steps
# Months
# April      13846.5
# August     12213.0
# December    8531.0
# February    9235.0
# January    10366.0
# July       10644.0
# June       12935.5
# March      11122.0
# May        11998.0
# November    9453.5
# October     7865.0
# September   9343.0

# %%
weekdays_vs_weekends = df_fitbit2.groupby('Work_or_Weekend').agg({'Steps':'median'})
weekdays_vs_weekends
# Out:
#                    Steps
# Work_or_Weekend
# 0                 9998.0
# 1                10445.5

# %%
weekdays_vs_weekends_fig, ax_fit = plt.subplots(nrows=1, ncols=0, figsize=(12,4))
weekdays_vs_weekends.plot(kind='bar')
plt.legend('weekdays VS. weekends steps')
plt.ylabel('weekdays - left VS. weekends - right', fontsize = 15, fontweight='bold')
plt.ylabel('number of steps', fontsize = 10, fontweight='bold')
# Out:
# Text(0, 0.5, 'number of steps')

# %%
month = ['Jan.', 'Feb.', 'Mar.', 'Apr.', 'May', 'Jun.', 'Jul.', 'Aug.', 'Sep.', 'Oct.', 'Nov.', 'Dec.']

median_steps_fig = plt.subplots(nrows = 1, ncols = 0, figsize=(15,20))
steps_median.plot(kind='line')
plt.legend('Months')
plt.xticks(range(13), month)
plt.xlabel('months', fontsize = 10, fontweight='bold')
plt.ylabel('number of steps',fontsize = 10, fontweight='bold')
#xsticks
#orientation 45°
# Out:
# Text(0, 0.5, 'number of steps')

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
list_columns = ['Minutes Lightly Active', 'Minutes Very Active', 'Minutes Sedentary']

# %%
list_color = ['rebeccapurple', 'green', 'olive', 'blue']

# %%
import random

# %%
for i in list_columns:
    plt.scatter(df_fitbit2[i], df_fitbit2['Steps'])
    plt.title(f"{i} vs. Steps", color = random.choice(list_color))
    plt.xlabel(f'{i}', fontsize = 10, fontweight='bold')
    plt.ylabel('number of steps', fontsize = 10, fontweight='bold')
    plt.show()

# %% [markdown]
# ## Challenge 3
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
driver = 'mysql+pymysql:'
driver   = 'mysql+pymysql:'
user     = 'data-students'
password = 'iR0nH@cK-D4T4B4S3'
ip       = '34.65.10.136'
database = 'titanic'
connection_string = f'{driver}//{user}:{password}@{ip}/{database}'
print(connection_string)

engine = create_engine(connection_string)
# Out:
# mysql+pymysql://data-students:iR0nH@cK-D4T4B4S3@34.65.10.136/titanic

# %%
pd.read_sql('SHOW TABLES', engine)
# Out:
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# c:\users\binardo surface\appdata\local\programs\python\python38\lib\site-packages\pymysql\connections.py in connect(self, sock)
#     580                         try:
# --> 581                             sock = socket.create_connection(
#     582                                 (self.host, self.port), self.connect_timeout,
#
# c:\users\binardo surface\appdata\local\programs\python\python38\lib\socket.py in create_connection(address, timeout, source_address)
#     806     if err is not None:
# --> 807         raise err
#     808     else:
#
# c:\users\binardo surface\appdata\local\programs\python\python38\lib\socket.py in create_connection(address, timeout, source_address)
#     795                 sock.bind(source_address)
# --> 796             sock.connect(sa)
#     797             # Break explicitly a reference cycle
#
# ...

# %%
df_titanic = pd.read_sql('SELECT * FROM titanic', engine)

# %%
df_titanic

# %%
df_titanic.to_csv('titanic.csv')

# %%
df_titanic = pd.read_csv('titanic.csv')

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
df_titanic = pd.read_csv('titanic.csv')
df_titanic.drop(columns='Unnamed: 0', inplace=True)

# %%
df_titanic
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1       0.0       3
# 1               2       1.0       1
# 2               3       1.0       3
# 3               4       1.0       1
# 4               5       0.0       3
# ...           ...       ...     ...
# 1304         1305       NaN       3
# 1305         1306       NaN       1
# 1306         1307       NaN       3
# 1307         1308       NaN       3
# 1308         1309       NaN       3
#
#                                                    Name  Gender        Age  \
# 0                               Braund, Mr. Owen Harris    male  22.000000
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                                Heikkinen, Miss. Laina  female  26.000000
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                              Allen, Mr. William Henry    male  35.000000
# ...

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
df_titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
# NUMERICAL VARIABLES
df_titanic.select_dtypes(['float64', 'int64'])
# Out:
#       PassengerId  Survived  Pclass        Age  SibSp  Parch      Fare
# 0               1       0.0       3  22.000000      1      0    7.2500
# 1               2       1.0       1  38.000000      1      0   71.2833
# 2               3       1.0       3  26.000000      0      0    7.9250
# 3               4       1.0       1  35.000000      1      0   53.1000
# 4               5       0.0       3  35.000000      0      0    8.0500
# ...           ...       ...     ...        ...    ...    ...       ...
# 1304         1305       NaN       3  29.513190      0      0    8.0500
# 1305         1306       NaN       1  39.000000      0      0  108.9000
# 1306         1307       NaN       3  38.500000      0      0    7.2500
# 1307         1308       NaN       3  29.513190      0      0    8.0500
# 1308         1309       NaN       3  25.315435      1      1   22.3583
#
# [1309 rows x 7 columns]

# %%
# CATEGORICAL VARIABLES
df_titanic.select_dtypes('object')
# Out:
#                                                    Name  Gender  \
# 0                               Braund, Mr. Owen Harris    male
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                                Heikkinen, Miss. Laina  female
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                              Allen, Mr. William Henry    male
# ...                                                 ...     ...
# 1304                                 Spector, Mr. Woolf    male
# 1305                       Oliva y Ocana, Dona. Fermina  female
# 1306                       Saether, Mr. Simon Sivertsen    male
# 1307                                Ware, Mr. Frederick    male
# 1308                           Peter, Master. Michael J    male
#
#                   Ticket Cabin Embarked
# 0              A/5 21171    U0        S
# 1               PC 17599   C85        C
# 2       STON/O2. 3101282    U0        S
# ...

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
titanic_plot, ax = plt.subplots(nrows = 1, ncols = 0, figsize=(12,6))

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
# age_plot, ax = plt.subplots(nrows = 1, ncols = 0, figsize=(20,10))
df_titanic['Age'].plot.hist(bins=25, alpha=1)

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
bin_list = [0,10,20,50]
age_plot2, ax = plt.subplots(nrows = 1, ncols = 0, figsize=(20,10))
df_titanic['Age'].plot.hist(bins=bin_list, alpha=1)

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
The Bin size regroups data in the required number of bins. It may make the plot unreadable
When too few bins are queried, or with two too different sizes regarding the data, the readability
of the plot is greatly reduced and may become unusable
"""

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
#calling Seaborn Distplot function to plot histogram with bin size determined automatically
age_titanic_seaborn = sns.distplot(df_titanic['Age'])

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
### Method 1 - matplotlib
plt.figure(figsize=(20,10))
df_titanic['Gender'].value_counts().plot(kind="bar", color = 'rebeccapurple')

# %%
# Method 2 - seaborn
sex_titanic_seaborn = sns.countplot(x=df_titanic['Gender'])

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
sns.countplot(df_titanic['Pclass'])

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
sns.distplot(df_titanic['Age'], kde=False, rug=True);

# %%
"""
A bar plot is used here in order to illustrate the different Age bins
"""

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
The Age is divided in an overall normal distribution, even if not perfectly normal, between several bins, 
mainly people between 20 & 40 years, with two important spikes around 25 and 30 years
"""

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
#way#1 with seaborn
age_sns = sns.boxenplot(df_titanic['Age'], saturation=1, width=0.5, palette="Set2")

# %%
plt.subplots(nrows=1, ncols=0, figsize=(20,10))
plt.boxplot(df_titanic['Age'], vert=False)
plt.xlabel('Age', fontsize='large', fontweight='bold')
# ax_age.set_xlabel('Age', fontsize='large', fontweight='bold')
# ax1.set_xlabel('x label', fontsize='xx-large', fontweight='bold')

# ax_age.set_title('Age distribution', fontsize='xx-large', fontweight='bold')
# Out:
# Text(0.5, 0, 'Age')

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
The boxplot provides with quartile divisions, which gives additional repartition information 
to the original simple histogram 
"""
# Out:
# '\nThe boxplot provides with quartile divisions, which gives additional repartition information to the original simple histogram \n'

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
fig, ax_fare_age = plt.figure(figsize=(20,10))
ax_fare_age.
ax_fare_age.set_title()
ax_fare_age.setxlabel()
ax_fare_age.setylabel()

# %%
# Method 2 - seaborn
fare_titanic_seaborn = sns.relplot('Age','Fare', data=df_titanic)

# %%
# Method 2 - seaborn
fare_titanic_seaborn = sns.jointplot('Age','Fare', data=df_titanic)

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
df_titanic_corr = df_titanic.corr()

# %%
fare_age_sns = sns.heatmap(df_titanic_corr, annot=True)

# %% [markdown]
# #### What are the most correlated features?

# %%
"""
Age & Pclass, as well as Age & Fare have medium negative correlation (c. -0.5)
"""

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
# your code here

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
g = sns.FacetGrid(df_titanic, col='Gender')
g.map(plt.hist, 'Age')
